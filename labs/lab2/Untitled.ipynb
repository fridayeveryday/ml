# %%
# %matplotlib qtk
# matplotlib.use('nbagg')
# import PyQt5

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

print(matplotlib.get_backend())
# Out:
# module://matplotlib_inline.backend_inline

# %%
fig = plt.figure()
ax_3d = fig.add_subplot(projection='3d')
x = np.linspace(0, 10, 50)
z = np.cos(x)
ax_3d.plot(x, x, z)
plt.show()

# %%
fig = plt.figure()
ax_3d = fig.add_subplot(projection='3d')
x = np.linspace(0, 10, 50)
z = np.cos(2*x)
ax_3d.plot(x, x, z)

ax_3d.set_xlabel('x')
ax_3d.set_ylabel('y')
ax_3d.set_zlabel('z')
plt.show()

# %%
x = [1, 2, 3]
y = [2, 5, 6, 8]
xgrid, ygrid = np.meshgrid(x,y)
xgrid[1,2], ygrid[1,2]
# Out:
# (3, 5)

# %%
x = np.arange(-2*np.pi, 2*np.pi, 0.2)
y = np.arange(-2*np.pi, 2*np.pi, 0.2)

# %%
xgrid, ygrid = np.meshgrid(x,y)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
zgrid = np.sin(xgrid) * np.sin(ygrid) / (xgrid * ygrid)

# %%
ax.plot_wireframe(xgrid, ygrid, zgrid)

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
# %matplotlib notebook

fig = plt.figure(dpi=200)
ax = fig.add_subplot(projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)
print(Y.shape)
# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# (120, 120)

# %%
fig = plt.figure(figsize=(9,6))
sub1 = fig.add_subplot(2,2,1)
sub2 = fig.add_subplot(2,2,2)
sub3 = fig.add_subplot(2,2,(3,4))

# %%
f,a=plt.subplots(2,3)
a[0,0].remove()
a[0,1].remove()
a[0,2].remove()
a[0,0] = f.add_subplot(2,3,(1,3))
plt.subplots_adjust(wspace= 1.25, hspace= 1.25)
a[0,0].plot([1,2,3], [1,2,3])

# %%
np.
# Out:
#   File "/tmp/ipykernel_26651/4178598045.py", line 1
#     TabNine::restart()
#             ^
# SyntaxError: invalid syntax

# %%
TabNine:restart
np.linspace
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_26651/768699061.py in <module>
# ----> 1 TabNine:restart
#       2
#
# NameError: name 'restart' is not defined

# %%
np.

# %%
np
